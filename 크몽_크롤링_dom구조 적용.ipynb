# %%
import os
os.chdir("C:/")
print(os.getcwd())
# Out:
# C:\

# %%
import pandas as pd
import selenium
from selenium import webdriver
import bs4
import requests
from tqdm import tqdm
#from bs4 import BeutifulSoup

# %%
driver = webdriver.Chrome('C:/Users/peopl/Downloads/chromedriver_win32/chromedriver.exe')
driver.implicitly_wait(1)

# %%
URL = 'https://kmong.com/category/10101?page=2&sort=ranking_points&online=false&company=false&is_prime=false&ratings=&meta=&is_it_portfolio=false'
driver.get(url=URL)

# %%
a1=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > h5')

a2=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(2) > div > a > div > div.GigList__description-wrapper > h5')

a3=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(3) > div > a > div > div.GigList__description-wrapper > h5')

a4=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(4) > div > a > div > div.GigList__description-wrapper > h5')

a5=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(5) > div > a > div > div.GigList__description-wrapper > h5')

# 디자이너 이름이 12 이후로 코드가 달라짐
a6=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

a7=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

a10=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

a11=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(2) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

a12=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(3) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

1
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-79-b9175f7bb24a> in <module>
#      12 a6=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')
#      13
# ---> 14 a7=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')
#      15
# ...

# %%
#####################dom 구조 적용으로 성공######################################

# 안긁히는 원본 a7=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')

a7=driver.find_element_by_css_selector('#router-view div div.Category__container div:nth-child(1) div.GigList__user-section h6')

print(a7.text, "주소 바뀐 디자이너 이름")
# Out:
# 로고마스터 주소 바뀐 디자이너 이름

# %%
#a6=driver.find_element_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child(1) > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')
a6=driver.find_element_by_css_selector(' #router-view div div.Category__container div:nth-child(1) div:nth-child(1) div.GigList__user-section h6')

print(a6.text, "디자이너 이름")
# Out:
# 로고마스터 디자이너 이름

# %%
b=[10101,10103,11301,11304,10706,10702,10707,10701,10705,10708,10801,10802,10803,10804,10601,10602,10201,10202,10203,10204,10501,10502,10503,10504,11101,11102,12401,12402,12403,10402,10404,11801,11803,10301,10302,12601,12602,12603,12604,114,122,117]

# %%
# result text files
raw_data=[]
cnt = 0 # 첫번째 페이지부터 순환하기 위함.

# go to the list (first page)

for i in b:
    while True:
        if cnt > 50: # 50p까지 돌림
            break
        
        cnt = cnt + 1
        print("category :"+str(i),'Page :'+str(cnt))
    
        driver.get('https://kmong.com/category/'+str(i)+'?page='+ str(cnt)+'&sort=ranking_points&online=false&company=false&is_prime=false&ratings=&meta=&is_it_portfolio=false') # 페이지 넘어가면 반복
        driver.implicitly_wait(1)
    
        # get articles link -> css copy
        for j in range(12):
            print("numberj:"+str(j+1))
            designer_name  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')  
            raw_data.append({ "designer_name": designer_name[0].text})
        for k in range(23):
            print("numberk:"+str(k+1))
            designer_name1  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div.LazyLoad.CategoryCardList__content > div:nth-child('+str(k+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')  
            raw_data.append({ "designer_name": designer_name1[0].text})    
            
data=pd.DataFrame(raw_data)     
data
# Out:
# category :10101 Page :1
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-116-5df4ebc00c78> in <module>
#      13         print("category :"+str(i),'Page :'+str(cnt))
#      14
# ---> 15         driver.get('https://kmong.com/category/'+str(i)+'?page='+ str(cnt)+'&sort=ranking_points&online=false&company=false&is_prime=false&ratings=&meta=&is_it_portfolio=false') # 페이지 넘어가면 반복
#      16         driver.implicitly_wait(1)
#      17
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
designer_name1
# Out:
# []

# %%
raw_data
# Out:
# [{'designer_name': '로고깎는남자'},
#  {'designer_name': 'g9com'},
#  {'designer_name': '로고고디자인'},
#  {'designer_name': 'DAcompany'},
#  {'designer_name': 'RamitwoDESIGN'},
#  {'designer_name': 'brand06'},
#  {'designer_name': '디자인업체'},
#  {'designer_name': '메이크홈즈'},
#  {'designer_name': '아이구배야'},
#  {'designer_name': '로고한잔'},
#  {'designer_name': '앨리스디자인'},
#  {'designer_name': '로고테리어'}]

# %% [markdown]
# [10101,
#  10103,
#  11301,
#  11304,
#  10706,
#  10702,
#  10707,
#  10701,
#  10705,
#  10708,
#  10801,
#  10802,
#  10803,
#  10804,
#  10601,
#  10602,
#  10201,
#  10202,
#  10203,
#  10204,
#  10501,
#  10502,
#  10503,
#  10504,
#  11101,
#  11102,
#  12401,
#  12402,
#  12403,
#  10402,
#  10404,
#  11801,
#  11803,
#  10301,
#  10302,
#  12601,
#  12602,
#  12603,
#  12604,
#  114,
#  122,
#  117]

# %%
del b[0] # 뽑은건 삭제하기 
# 11304 안됨

b
# Out:
# [11101,
#  11102,
#  12401,
#  12402,
#  12403,
#  10402,
#  10404,
#  11801,
#  11803,
#  10301,
#  10302,
#  12601,
#  12602,
#  12603,
#  12604,
#  114,
#  122,
#  117]

# %%
# 최종 코드 *************************************************************************
raw_data=[]


# go to the list (first page)

for i in tqdm(b):
    cnt = 0 # 첫번째 페이지부터 순환하기 위함.
    while True:
        if cnt > 30: # 50p까지 돌림
            break
        
        cnt = cnt + 1
        print("category :"+str(i),'Page :'+str(cnt))
    
        driver.get('https://kmong.com/category/'+str(i)+'?page='+ str(cnt)+'&sort=ranking_points&online=false&company=false&is_prime=false&ratings=&meta=&is_it_portfolio=false') # 페이지 넘어가면 반복
        driver.implicitly_wait(1)
    
        # get articles link -> css copy
        for j in range(12):
            
            print("numberj:"+str(j+1))
            category = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategorySiteMap > div ')
            designer_name  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')   
            post = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > h5')
            price = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__bottom-wrapper > div.GigList__price-wrapper > div.GigList__price > span')
            star = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-average')
            reviews  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-count')    
            
            if len(designer_name)==0 or len(post)==0 or len(price)==0 or len(star)==0 or len(reviews)==0 :
                break
            raw_data.append({"category":category[0].text , "designer_name": designer_name[0].text,"post": post[0].text,"price": price[0].text,"star": star[0].text,"reviews": reviews[0].text})
# Out:
#   0%|                                                                                           | 0/18 [00:00<?, ?it/s]
# category :11101 Page :1
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# category :11101 Page :2
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# category :11101 Page :3
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# category :11101 Page :4
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# category :11101 Page :5
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# ...

# %%
data=pd.DataFrame(raw_data)     
data
# Out:
#                                  category designer_name  \
# 0    홈\n>\n디자인\n>\n웹툰·캐릭터·이모티콘\n>\n웹툰·캐릭터           꼬맹E
# 1    홈\n>\n디자인\n>\n웹툰·캐릭터·이모티콘\n>\n웹툰·캐릭터       귀여운야채곱창
# 2    홈\n>\n디자인\n>\n웹툰·캐릭터·이모티콘\n>\n웹툰·캐릭터          오리파크
# 3    홈\n>\n디자인\n>\n웹툰·캐릭터·이모티콘\n>\n웹툰·캐릭터        스튜디오연빵
# 4    홈\n>\n디자인\n>\n웹툰·캐릭터·이모티콘\n>\n웹툰·캐릭터          닥터수제
# ..                                    ...           ...
# 830                      홈\n>\n디자인\n>\n기타          무르무르
# 831                      홈\n>\n디자인\n>\n기타       Biotech
# 832                      홈\n>\n디자인\n>\n기타       ssysysy
# 833                      홈\n>\n디자인\n>\n기타        굿데이디자인
# 834                      홈\n>\n디자인\n>\n기타            화시
#
#                                   post    price star   reviews
# 0    웹툰,커미션,일러스트,팬아트 등 모든 만화 제작해 드립니다.   10,000  5.0    1개의 평가
# 1             귀엽고 아기자기한 캐리커쳐를 그려 드립니다.   10,000  5.0    2개의 평가
# 2                가치를 담은 캐릭터를 제작해 드립니다.   90,000  4.9  334개의 평가
# ...

# %%
data8=data# 11101, 11102, 12401, 12402, 12403, 10402, 10404, 11801, 11803, 10301, 10302, 12601, 12602, 12603, 12604, 114, 122, 117

# %%
data7=data#10202, 10203, 10204, 10501, 10502, 10503, 10504

# %%
data5=data#10802, 10803, 10804, 10601, 10602, 10201,

# %%
data4=data # 10707, 10701, 10705, 10708, 10801

# %%
data3=data # 10702

# %%
data2=data# 10706

# %%
data1=data # 10101, 10103, 11301

# %%
data_final=pd.concat([data1,data2,data3,data4,data5,data7,data8],ignore_index=True)

# %%
# 합쳐서 한꺼번에
data_final.to_csv('C:/data/kmong_crawling.csv')

# %% [markdown]
# # DOM구조 적용해 한번에 긁기

# %%
b=[10101,
 10103,
 11301,
 11304,
 10706,
 10702,
 10707,
 10701,
 10705,
 10708,
 10801,
 10802,
 10803,
 10804,
 10601,
 10602,
 10201,
 10202,
 10203,
 10204,
 10501,
 10502,
 10503,
 10504,
 11101,
 11102,
 12401,
 12402,
 12403,
 10402,
 10404,
 11801,
 11803,
 10301,
 10302,
 12601,
 12602,
 12603,
 12604,
 114,
 122,
 117]

# %%
b=[12601,
 12602,
 12603,
 12604,
 114,
 122,
 117]

# %%
# 돔구조 활용시 구조가 겹치고 말단위주로 띄어쓰기 없이 작성!!!
a7=driver.find_element_by_css_selector('#router-view div div.Category__container div:nth-child(1) div.GigList__user-section h6')


print(a7.text, "주소 바뀐 디자이너 이름")
# Out:
# 로고마스터 주소 바뀐 디자이너 이름

# %%
# 최종 코드 *************************************************************************
raw_data=[]


# go to the list (first page)

for i in tqdm(b):
    cnt = 0 # 첫번째 페이지부터 순환하기 위함.
    while True:
        if cnt > 50: # 50p까지 돌림
            break
        
        cnt = cnt + 1
        print("category :"+str(i),'Page :'+str(cnt))
    
        driver.get('https://kmong.com/category/'+str(i)+'?page='+ str(cnt)+'&sort=ranking_points&online=false&company=false&is_prime=false&ratings=&meta=&is_it_portfolio=false') # 페이지 넘어가면 반복
        driver.implicitly_wait(1)
    
        # get articles link -> css copy
        for j in range(12):
            
            print("numberj:"+str(j+1))
            category = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategorySiteMap > div ')
            designer_name  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__user-section > div > h6')   
            post = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > h5')
            price = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__bottom-wrapper > div.GigList__price-wrapper > div.GigList__price > span')
            star = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-average')
            reviews  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-count')    
            
            if len(designer_name)==0 or len(post)==0 or len(price)==0 or len(star)==0 or len(reviews)==0 :
                break
            raw_data.append({"category":category[0].text , "designer_name": designer_name[0].text,"post": post[0].text,"price": price[0].text,"star": star[0].text,"reviews": reviews[0].text})
        for k in range(23):
            print("numberk:"+str(k+1))
            category = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategorySiteMap > div ')
            designer_name1  = driver.find_elements_by_css_selector('#router-view div div.Category__container div:nth-child('+str(k+1)+') div.GigList__user-section h6')  
            post = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > h5')
            price = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.GigList__bottom-wrapper > div.GigList__price-wrapper > div.GigList__price > span')
            star = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-average')
            reviews  = driver.find_elements_by_css_selector('#router-view > div > div.Category__container > main > div > div.CategoryCardList > div:nth-child(1) > div:nth-child('+str(j+1)+') > div > a > div > div.GigList__description-wrapper > div.flex-center-bottom > div > div > h6.GigList__rate-count')    
            if len(designer_name1)==0 or len(post)==0 or len(price)==0 or len(star)==0 or len(reviews)==0 :
                break
            raw_data.append({"category":category[0].text , "designer_name": designer_name1[0].text,"post": post[0].text,"price": price[0].text,"star": star[0].text,"reviews": reviews[0].text})
# Out:
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
# category :12601 Page :1
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberj:9
# numberj:10
# numberj:11
# numberj:12
# numberk:1
# numberk:2
# numberk:3
# numberk:4
# numberk:5
# numberk:6
# numberk:7
# numberk:8
# numberk:9
# numberk:10
# numberk:11
# numberk:12
# numberk:13
# category :12601 Page :2
# numberj:1
# numberj:2
# numberj:3
# numberj:4
# numberj:5
# numberj:6
# numberj:7
# numberj:8
# numberk:1
# category :12601 Page :3
# numberj:1
# numberk:1
# category :12601 Page :4
# numberj:1
# numberk:1
# category :12601 Page :5
# numberj:1
# numberk:1
# category :12601 Page :6
# numberj:1
# numberk:1
# category :12601 Page :7
# numberj:1
# numberk:1
# category :12601 Page :8
# numberj:1
# numberk:1
# category :12601 Page :9
# numberj:1
# numberk:1
# category :12601 Page :10
# numberj:1
# numberk:1
# ...

# %%
data_final_3=pd.DataFrame(raw_data)     
data_final_3
# Out:
#                          category designer_name  \
# 0   홈\n>\n디자인\n>\n게임·VR\n>\n게임용원화           홀리덕
# 1   홈\n>\n디자인\n>\n게임·VR\n>\n게임용원화            볼고
# 2   홈\n>\n디자인\n>\n게임·VR\n>\n게임용원화           크레노
# 3   홈\n>\n디자인\n>\n게임·VR\n>\n게임용원화           홀리덕
# 4   홈\n>\n디자인\n>\n게임·VR\n>\n게임용원화           히요J
# ..                            ...           ...
# 58  홈\n>\n디자인\n>\n게임·VR\n>\nVR·AR         uniku
# 59  홈\n>\n디자인\n>\n게임·VR\n>\nVR·AR        ahndam
# 60  홈\n>\n디자인\n>\n게임·VR\n>\nVR·AR          뷰마스터
# 61  홈\n>\n디자인\n>\n게임·VR\n>\nVR·AR         Wed3D
# 62  홈\n>\n디자인\n>\n게임·VR\n>\nVR·AR      BCcreate
#
#                                   post      price star  reviews
# 0             최고 퀄리티의 도트 그래픽 작업해 드립니다.     30,000  5.0   5개의 평가
# 1        원하시는 느낌의 픽셀, 도트를 정성껏 찍어 드립니다.     10,000  5.0  19개의 평가
# 2             게임 캐릭터 원화, 일러스트 그려 드립니다.     40,000  5.0   4개의 평가
# 3                   캐릭터 일러스트 만들어 드립니다.    200,000  5.0   1개의 평가
# ...

# %%
data_final_3

# %%
data_final_2

# %%
data_final_dom=pd.concat([data_final_3,data_final_2],ignore_index=True)

# %%
data_final_dom.to_csv('C:/data/kmong_crawling_2.csv')
